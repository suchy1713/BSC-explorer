# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ref = [[0, 105], [0, 0]]
refh = [[0, 0], [0, 68]]

vec1 = [[50, 50], [20, 39]]
vec2 = [[50, 52], [20, 42]]

vec2_vector = [2, 22]
vec1_vector = [4, 19]
print(np.dot(vec2_vector/np.linalg.norm(vec2_vector), vec1_vector/np.linalg.norm(vec1_vector)))

plt.plot(ref[0], ref[1])
plt.plot(refh[0], refh[1])
plt.plot(vec1[0], vec1[1])
plt.plot(vec2[0], vec2[1])
plt.show()
# Out:
# 0.9931823956531611
